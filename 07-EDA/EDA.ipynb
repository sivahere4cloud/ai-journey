# %% [markdown]
# Kaggle
# ======
#
# => kaggle is repositroy accessed by entire world datascientist, data analyst, busines analyst
#
# kaggle -- datascience ( ml & ai datasets are available hear ( dataset + coding)
# uci -- datascience ( only ml & ai dataset are availabe( only dataset is available)
# huggingface -- gen ai , llm developer, agentic ai  ( llm model dataset, transformer, architecture, open sourec,)

# %% [markdown]
# ===============================================================
#                         DAY 1
# ===============================================================
#
# EDA= Explaratory Data Analyst
#  => Foundation of Machine Learning
#  => covert from raw - clean technique are called EDA technique
#  EDA Techniques are......
#
# 1- variable identification
# 2- univariate analysis
# 3- bivariate analysis
# 4- outlier treatment
# 5- missing value treatment
# 6- imputation or transformer
# 7- variable creation
# ===========================================================================================
# 1- Variable identification
#
# Family ( loan, kids education, house propery)
# 	father (govtempy) -- dependent variable = target variable = predicted variable = y
# 	mother ( home) - Independent variable == non target variable = non predicted attribuete (x1)
# 	son ( 2nd) - Independent variable == non target variable = non predicted attribuete (x2)
# 	daughter (5th) - Independent variable == non target variable = non predicted attribuete (x3)
#
# y = x1 + x2 + x3
# y = m1x1 + m2x2 + m3x3 ( multiple linear regressiona algorithm)
#
# Family
# 		father -- y
# 		mother - x1
#
# linear equation - y = mx + c (simple linear regression algorithm)
#
# 1- variable identification
# 	independent variable == x1, x2, x3
# 	dependent variable = y
#
# ----
# machine learning -->
# ---
# 1- Regression -- Dependent variable are continuous
# 2- Classification -- dependet variable are binary or categorical
# 3- Clustering -- no depend variable but group
#
# 1- REGRESSION Model
# 		what is mean by continuous variable
# 	gold price
# 	petorl price
# 	flight fare prices
# 	electricit bill prices
# 	house price
# 	land price
# 	stock price
# 	crypto
# 	food price
# 	employ salary
# 	company sales
# 	ev car sales
#
# to build these project we will apply regression algorithm ->
#
# 	1- simple linear regression
# 	2- multiple linear regression
# 	3- polynomial regression
# 	4- gradient descend, stocastic gradient descent,batch gradient descend
# 	5- k nearest neighbout
# 	6- support vector regressor
# 	7- decission tree regressor
# 	8- xgboost regressor
# 	9- light gradient boosting regressor
# 	10- ann regressor
# 	11- time series
# ===============================================================
# 2- classification - dependent variable is binary or category
#
# pass ~ fail pass -1 & 0
# profit or loss
# y or n
# cat or dog
# spam or non spam
# defaulter or non defaulter
# +ve revew or -ve review
# churn or not
# exit or not
# hit or flop
# hot or cold
#
# classification algorithm
#
# 		1- logistic regression
# 		2- support vector machine
# 		3- knn classifier
# 		4- naive bayes (bayesian theorem)
# 		5- decission tree
# 		6- random forest
# 		7- xgboost
# 		8- lgbm
# 		9- ann classifier
#
# 3- clustering ( grouping)
# 	pca ( principal component analsis)
# 	k-means
# 	hierarchicla
# 	dbscan
# ==============================================================================================
# ML Flow
# =======
#
# DATA CLEANING OR data cleansing -- raw data - clean data - ml model - predict  - deplpy - mlops - cicd
#
# raw data
# data cleaning
# clean data
# eda technique
# statistical graph
# data preprocessing pipeline
# ml model building
# ml testing
# deployment
# mlops
# cicd piplin
# --- new raw data will come
# ===============================================================
#
#
# ===============================================================
#                         DAY 2
# ===============================================================
#
# 1- VARIABLE IDENTIFICATION
# 	IV == X1, X2, X3
# 	DV == Y
# 	Relevant attribute
# 	Irrelevant attribute
#
# every time being data science we need to look for relevant attribute
#
# if you build the ml model with irrelevant attribute then overfitting | multicollinearity
# 1st technique we are understood well
#
# 2. Univariate analysis ( plot the graph using 1 variable)
#
# 3. Bivariate analysis ( plot the graph using 2 variable)
#
# 	CORELATION - Relation among attributes in the dataset
# 	range of the corelation is -1 to 1
#
# 	+ve corr ( 0 to 1)
# 	-ve corr ( -1 to 0)
# 	0 corr (0) neither +Ve nor negative
#
#
# 4- missing value treatment -->
# 	dataset build with numerical data & categorical data
#
# if numerical data is missing then we need to implement
# 	mean strategy
# 	median strategy
# 	mode strategy
#
# if categorical data is missing then we need to implement
# 	MODE strategy
# 	KNN strategy(k nearest neighbour)
#
# 5- OUTLIER TREATMENT
# 	by plot the graph
#
# 6- IMPUTATION or TRANSFORMER
#
#
# TRANSFORMER -- TRANSFORM categorical data  numerical data to build ml model
# TRANSFORMER also called as IMPUTEATIOON TECHNIQUE
#
# NLP -- This technique we called EMBEDDING
#
# transformer are 3 types -->
# 	dummy variable
# 	one hot encoder
# 	label encoder
#
# 7- variable creation
# 	from 1 variable we will create more attribute
# 	variable creation
#
# == EDA technical concept was completed ===
# == EDA also called as FEATURE ENGINEERING TECHNQUE ===
#
# == EDA PRACTICLE ==
# Does outlier impact mean, median , mode
# ===> mean strategy impact by outlier
# ================================================================
# .get_dummies() -- it will help to convert categoriacal data to number
#
#
# === LLM MODEL
# === EDA + LLM to build automization
#
#
# 1st step - google - ollama - donwload & install
# 2nd ste - cmd - ollama
# 3rd setp - ollama list ( empty for 1st time user)
# 4th step - ollama pull mistral | ollama pull deepsekk
